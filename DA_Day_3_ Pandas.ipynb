# %%
#pandas
import pandas as pd
#pd.Series(column name,index=[]) we can give either numbers ass index or we can give a list
a=["madhur","naveen","binnu","anuragh"]
b=[11,22,33,44]
r=pd.Series(a,index=b)
res=pd.Series(a,index=[1,2,3,4])
print(r)
print(res)
# Out:
# 11     madhur
# 22     naveen
# 33      binnu
# 44    anuragh
# dtype: object
# 1     madhur
# 2     naveen
# 3      binnu
# 4    anuragh
# dtype: object

# %%
#loading csv file
dia=pd.read_csv("/content/diabetcsv.csv")#read_csv is only for text and csv
gra=pd.read_csv("//content/demodt.txt",sep=",")
dem=pd.read_excel("/content/diabetes.xlsx",sheet_name="dora")#use read_excel for excel
dia
gra
dem
# Out:
#   Dead Alive
# 0  yes    no
# 1  yes    no
# 2  yes    no
# 3  yes    no
# 4  yes    no

# %%
dem=pd.read_excel("/content/diabetes.xlsx",sheet_name="dora")
gradescsv=pd.read_csv("/content/grades_withnulls.csv")
dem.describe()
print(dem.shape)#returns no of rows and columns
print(dem.shape[0])#returns no of rows if 0
print(dem.shape[1])#returns no of columns if 1
print(gradescsv.isnull())#returns where null values are present. NaN is nothing but not a number
#syntax is variable.isnull()
print(gradescsv.isnull().sum())#returns the total no of true(true in the sense null) values in every column
# Out:
# (5, 2)
# 5
# 2
#     Names  Initials   SEM1   SEM2   SEM3  Grade  Placed
# 0   False     False  False  False  False  False   False
# 1   False     False  False  False  False  False   False
# 2   False     False  False  False  False  False   False
# 3   False     False  False  False   True  False   False
# 4   False     False  False  False  False  False   False
# 5   False     False  False  False  False  False   False
# 6   False     False  False  False  False  False   False
# 7   False     False  False  False  False  False   False
# 8   False     False   True  False  False  False   False
# 9   False     False   True  False  False  False   False
# 10  False     False   True  False  False  False   False
# 11  False     False  False  False  False  False   False
# 12  False     False  False  False  False  False   False
# 13  False     False  False  False  False  False   False
# 14  False     False  False  False  False  False   False
# ...

# %%
#data cleaning is nothing but removing null values
#it can be done in two ways
#save the returned data in another file or use inplace=True
print(gradescsv.dropna())#returns the file with deleted rows of NaN values but the new file is not replaced with the original one
print("Dropna deletes the rows with NaN values but it wont reflect in the original file")
print(gradescsv)
print("as dropna returns the new file, assign it to new variable so that changes will be stored")
gc=gradescsv.dropna()
print("changes of gradescsv is stored in gc")
print(gc)
print("Another way is use dropna(inplace=True). Now the changes will be reflect to the original file")
gradescsv.dropna(inplace=True)
print(gradescsv)
# Out:
#      Names Initials  SEM1  SEM2  SEM3 Grade  Placed
# 0      Joe        K   9.8  10.0   9.9    A+       1
# 1   Rajesh        M   8.9   9.1   9.3     A       1
# 2   Kissan        V   9.9   9.8  10.0     A       0
# 4     Jeen        K   9.8   9.1   9.9    A+       1
# 5      Raj        M   8.9   9.1   9.3     A       1
# 6   Hassan        V   9.9   9.0   9.2     A       1
# 7     Mari        N   7.7   8.0   7.1     B       1
# 11    Maya        N   7.7   8.0   7.1     B       0
# 12   Jolin        K   9.8   9.1   9.9    A+       1
# 13  Rajesh        M   8.9   9.1   9.3     A       1
# 14    Riya        M   9.3   9.9  10.0     A       1
# 15    Sana        V   9.9   9.3   9.2     A       0
# 16    Mark        N   7.7   8.0   7.0     B       0
# Dropna deletes the rows with NaN values but it wont reflect in the original file
#      Names Initials  SEM1  SEM2  SEM3 Grade  Placed
# 0      Joe        K   9.8  10.0   9.9    A+       1
# ...

# %%
df=pd.read_csv("/content/grades_withnulls.csv")
print(df.fillna(555))
df
df.fillna(555,inplace=True)
print(df)
# Out:
#      Names Initials   SEM1  SEM2   SEM3 Grade  Placed
# 0      Joe        K    9.8  10.0    9.9    A+       1
# 1   Rajesh        M    8.9   9.1    9.3     A       1
# 2   Kissan        V    9.9   9.8   10.0     A       0
# 3     Mary        N    7.7   8.0  555.0     B       0
# 4     Jeen        K    9.8   9.1    9.9    A+       1
# 5      Raj        M    8.9   9.1    9.3     A       1
# 6   Hassan        V    9.9   9.0    9.2     A       1
# 7     Mari        N    7.7   8.0    7.1     B       1
# 8     Jess        K  555.0   9.1    9.9    A+       1
# 9   Rajini        M  555.0   9.1    9.3     A       0
# 10   Kiran        V  555.0   9.3    9.2     A       0
# 11    Maya        N    7.7   8.0    7.1     B       0
# 12   Jolin        K    9.8   9.1    9.9    A+       1
# 13  Rajesh        M    8.9   9.1    9.3     A       1
# 14    Riya        M    9.3   9.9   10.0     A       1
# 15    Sana        V    9.9   9.3    9.2     A       0
# ...

# %%
import pandas as pd
df2=pd.read_csv("/content/grades_withnulls.csv")
mv=df2['SEM1'].mean()
print(mv)
df2.fillna(mv,inplace=True)
print(df2)
# Out:
# 8.992857142857144
#      Names Initials      SEM1  SEM2       SEM3 Grade  Placed
# 0      Joe        K  9.800000  10.0   9.900000    A+       1
# 1   Rajesh        M  8.900000   9.1   9.300000     A       1
# 2   Kissan        V  9.900000   9.8  10.000000     A       0
# 3     Mary        N  7.700000   8.0   8.992857     B       0
# 4     Jeen        K  9.800000   9.1   9.900000    A+       1
# 5      Raj        M  8.900000   9.1   9.300000     A       1
# 6   Hassan        V  9.900000   9.0   9.200000     A       1
# 7     Mari        N  7.700000   8.0   7.100000     B       1
# 8     Jess        K  8.992857   9.1   9.900000    A+       1
# 9   Rajini        M  8.992857   9.1   9.300000     A       0
# 10   Kiran        V  8.992857   9.3   9.200000     A       0
# 11    Maya        N  7.700000   8.0   7.100000     B       0
# 12   Jolin        K  9.800000   9.1   9.900000    A+       1
# 13  Rajesh        M  8.900000   9.1   9.300000     A       1
# ...

# %%
#access the data
#iloc=interger location,index
#loc=field names, index
df2.loc[0]#details of 0 record will be printed
#syntax: variable.loc[start:stop:step,"field_name"]#similar to string slicing but stop is inclusive
#variable.loc[row_index,"column_name"]
# Out:
# Names        Joe
# Initials       K
# SEM1         9.8
# SEM2        10.0
# SEM3         9.9
# Grade         A+
# Placed         1
# Name: 0, dtype: object

# %%
df2.loc[0:5:2]#here stop is inclusive
# Out:
#     Names Initials  SEM1  SEM2  SEM3 Grade  Placed
# 0     Joe        K   9.8  10.0   9.9    A+       1
# 2  Kissan        V   9.9   9.8  10.0     A       0
# 4    Jeen        K   9.8   9.1   9.9    A+       1

# %%
print(df2.loc[0:5,"SEM1"])#we can get particular field by entering its name
print(df2.loc[0,"SEM1"])#variable.loc[row_index,"column_name"]
print(df2.iloc[0:5,0:2])#doubt iloc id not label based so it prints the values in data frame from 0 to 5 where as loc is label based
#so if we dont have 3rd record in the data frame it prints only 0,1,2,4,5
# Out:
# 0    9.8
# 1    8.9
# 2    9.9
# 3    7.7
# 4    9.8
# 5    8.9
# Name: SEM1, dtype: float64
# 9.8
#     Names Initials
# 0     Joe        K
# 1  Rajesh        M
# 2  Kissan        V
# 3    Mary        N
# 4    Jeen        K

# %%
#accessing elements
print(df2[df2.index==7])
print(df2.loc[10:15])#doubt
print(df2.iloc[10:15])
print(df2.loc[0:5])
print(df2.iloc[0:5])
# Out:
#   Names Initials  SEM1  SEM2  SEM3 Grade  Placed
# 7  Mari        N   7.7   8.0   7.1     B       1
#     Names Initials      SEM1  SEM2  SEM3 Grade  Placed
# 10  Kiran        V  8.992857   9.3   9.2     A       0
# 11   Maya        N  7.700000   8.0   7.1     B       0
# 12  Jolin        K  9.800000   9.1   9.9    A+       1
# 14   Riya        M  9.300000   9.9  10.0     A       1
# 15   Sana        V  9.900000   9.3   9.2     A       0
#     Names Initials      SEM1  SEM2  SEM3 Grade  Placed
# 10  Kiran        V  8.992857   9.3   9.2     A       0
# 11   Maya        N  7.700000   8.0   7.1     B       0
# 12  Jolin        K  9.800000   9.1   9.9    A+       1
# 14   Riya        M  9.300000   9.9  10.0     A       1
# 15   Sana        V  9.900000   9.3   9.2     A       0
#     Names Initials  SEM1  SEM2       SEM3 Grade  Placed
# 0     Joe        K   9.8  10.0   9.900000    A+       1
# 1  Rajesh        M   8.9   9.1   9.300000     A       1
# ...

# %%
df2[df2.Grade=='A']
# Out:
#      Names Initials      SEM1  SEM2  SEM3 Grade  Placed
# 1   Rajesh        M  8.900000   9.1   9.3     A       1
# 2   Kissan        V  9.900000   9.8  10.0     A       0
# 5      Raj        M  8.900000   9.1   9.3     A       1
# 6   Hassan        V  9.900000   9.0   9.2     A       1
# 9   Rajini        M  8.992857   9.1   9.3     A       0
# 10   Kiran        V  8.992857   9.3   9.2     A       0
# 13  Rajesh        M  8.900000   9.1   9.3     A       1
# 14    Riya        M  9.300000   9.9  10.0     A       1
# 15    Sana        V  9.900000   9.3   9.2     A       0

# %%
#print the records who scored 9.3 in sem3
print(df2[df2.SEM3==9.3])
print(df2.loc[df2.SEM1>9.8,"Names"])
# Out:
#      Names Initials      SEM1  SEM2  SEM3 Grade  Placed
# 1   Rajesh        M  8.900000   9.1   9.3     A       1
# 5      Raj        M  8.900000   9.1   9.3     A       1
# 9   Rajini        M  8.992857   9.1   9.3     A       0
# 13  Rajesh        M  8.900000   9.1   9.3     A       1
# 2     Kissan
# 6     Hassan
# 15      Sana
# Name: Names, dtype: object

# %%
df2.loc[df2.SEM3>9,"Grade"]
# Out:
# 0     A+
# 1      A
# 2      A
# 4     A+
# 5      A
# 6      A
# 8     A+
# 9      A
# 10     A
# 12    A+
# 13     A
# 14     A
# 15     A
# Name: Grade, dtype: object

# %%
print(df2.drop_duplicates())#changes are not reflected
print(df2)
df2.drop_duplicates(inplace=True)#changes reflected
print(df2)
# Out:
#      Names Initials      SEM1  SEM2       SEM3 Grade  Placed
# 0      Joe        K  9.800000  10.0   9.900000    A+       1
# 1   Rajesh        M  8.900000   9.1   9.300000     A       1
# 2   Kissan        V  9.900000   9.8  10.000000     A       0
# 3     Mary        N  7.700000   8.0   8.992857     B       0
# 4     Jeen        K  9.800000   9.1   9.900000    A+       1
# 5      Raj        M  8.900000   9.1   9.300000     A       1
# 6   Hassan        V  9.900000   9.0   9.200000     A       1
# 7     Mari        N  7.700000   8.0   7.100000     B       1
# 8     Jess        K  8.992857   9.1   9.900000    A+       1
# 9   Rajini        M  8.992857   9.1   9.300000     A       0
# 10   Kiran        V  8.992857   9.3   9.200000     A       0
# 11    Maya        N  7.700000   8.0   7.100000     B       0
# 12   Jolin        K  9.800000   9.1   9.900000    A+       1
# 14    Riya        M  9.300000   9.9  10.000000     A       1
# ...

# %%
df2.tail()#by default value is 5
df2.head()#by default value is 5
df2.head(2)
df2.tail(2)
# Out:
#   Names Initials  SEM1  SEM2  SEM3 Grade  Placed
# 7  Mari        N   7.7   8.0   7.1     B       1

# %%
#columns
col=list(df2.columns)
print(col)
# Out:
# ['Names', 'Initials', 'SEM1', 'SEM2', 'SEM3', 'Grade', 'Placed']

# %%
print(df2.rename(columns={'GPA':'GPAa'}))#changes are not reflected
print(df2)
df2.rename(columns={'GPA':'GPAa'},inplace=True)#changes will be reflected
print(df2)
# Out:
#      Names Initials      SEM1  SEM2       SEM3 Grade  Placed
# 0      Joe        K  9.800000  10.0   9.900000    A+       1
# 1   Rajesh        M  8.900000   9.1   9.300000     A       1
# 2   Kissan        V  9.900000   9.8  10.000000     A       0
# 3     Mary        N  7.700000   8.0   8.992857     B       0
# 4     Jeen        K  9.800000   9.1   9.900000    A+       1
# 5      Raj        M  8.900000   9.1   9.300000     A       1
# 6   Hassan        V  9.900000   9.0   9.200000     A       1
# 7     Mari        N  7.700000   8.0   7.100000     B       1
# 8     Jess        K  8.992857   9.1   9.900000    A+       1
# 9   Rajini        M  8.992857   9.1   9.300000     A       0
# 10   Kiran        V  8.992857   9.3   9.200000     A       0
# 11    Maya        N  7.700000   8.0   7.100000     B       0
# 12   Jolin        K  9.800000   9.1   9.900000    A+       1
# 14    Riya        M  9.300000   9.9  10.000000     A       1
# ...

# %%
df2["Conduct"]="Good"
df2["Average"]=(df2["SEM1"]+df2["SEM2"]+df2["SEM3"])/3
df2
# Out:
#      Names Initials      SEM1  SEM2       SEM3 Grade  Placed Conduct   Average
# 0      Joe        K  9.800000  10.0   9.900000    A+       1    Good  9.900000
# 1   Rajesh        M  8.900000   9.1   9.300000     A       1    Good  9.100000
# 2   Kissan        V  9.900000   9.8  10.000000     A       0    Good  9.900000
# 3     Mary        N  7.700000   8.0   8.992857     B       0    Good  8.230952
# 4     Jeen        K  9.800000   9.1   9.900000    A+       1    Good  9.600000
# 5      Raj        M  8.900000   9.1   9.300000     A       1    Good  9.100000
# 6   Hassan        V  9.900000   9.0   9.200000     A       1    Good  9.366667
# 7     Mari        N  7.700000   8.0   7.100000     B       1    Good  7.600000
# 8     Jess        K  8.992857   9.1   9.900000    A+       1    Good  9.330952
# 9   Rajini        M  8.992857   9.1   9.300000     A       0    Good  9.130952
# 10   Kiran        V  8.992857   9.3   9.200000     A       0    Good  9.164286
# ...

# %% [markdown]
# Data visualization using pandas

# %%
df2[['SEM1','SEM2']].plot.line()#plots sem1 and sem2 on single graph
df2[['SEM1','SEM2']].plot.line(subplots=True)#plots sem1 and sem2 on separate graphs
df2.plot.line()#plots all the columns on a single graph
df2.plot.line(subplots=True)#plots all the columns on a separate graphs
# Out:
# array([<Axes: >, <Axes: >, <Axes: >, <Axes: >, <Axes: >], dtype=object)

# %%
df2.plot(kind="scatter",x="Names",y="Average")
df2.plot(kind="line",x="Names",y="Average")
df2.plot(kind="hist",x="Names",y="Average")
# Out:
# <Axes: ylabel='Frequency'>

# %%
df2
# Out:
#      Names Initials      SEM1  SEM2       SEM3 Grade  Placed Conduct   Average
# 0      Joe        K  9.800000  10.0   9.900000    A+       1    Good  9.900000
# 1   Rajesh        M  8.900000   9.1   9.300000     A       1    Good  9.100000
# 2   Kissan        V  9.900000   9.8  10.000000     A       0    Good  9.900000
# 3     Mary        N  7.700000   8.0   8.992857     B       0    Good  8.230952
# 4     Jeen        K  9.800000   9.1   9.900000    A+       1    Good  9.600000
# 5      Raj        M  8.900000   9.1   9.300000     A       1    Good  9.100000
# 6   Hassan        V  9.900000   9.0   9.200000     A       1    Good  9.366667
# 7     Mari        N  7.700000   8.0   7.100000     B       1    Good  7.600000
# 8     Jess        K  8.992857   9.1   9.900000    A+       1    Good  9.330952
# 9   Rajini        M  8.992857   9.1   9.300000     A       0    Good  9.130952
# 10   Kiran        V  8.992857   9.3   9.200000     A       0    Good  9.164286
# ...

# %%
df2.to_csv("df2.csv")#data_frame_name.to_csv("Filename.csv")
